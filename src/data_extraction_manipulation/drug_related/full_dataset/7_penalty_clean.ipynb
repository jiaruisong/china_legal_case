# %% [markdown]
# # number of csv files that have misplaced columns

# %%
import os
import pandas as pd

# Define the directory containing the CSV files
source_directory = '/Users/jiaruisong/Documents/Coding/INFO 288 Big Data and Development_Data/drug_related_full_dataset_type_amount_cleaned_penalty'

# Initialize a counter
count_files_with_more_than_20_columns = 0
number_of_files = 0

# Loop through each file in the source directory
for filename in os.listdir(source_directory):
    if filename.endswith('.csv'):  # Check if the file is a CSV
        file_path = os.path.join(source_directory, filename)
        number_of_files += 1
        
        # Try to read the CSV file
        try:
            df = pd.read_csv(file_path)
            # Check if the CSV file has more than 20 columns
            if df.shape[1] > 19:
                count_files_with_more_than_20_columns += 1
        except Exception as e:
            print(f'Failed to process {filename}: {e}')

# Print the total count of files with more than 20 columns
print(f"Total CSV files with more than 19 columns: {count_files_with_more_than_20_columns}")
print(f"Total number of CSV files: {number_of_files}")
# Out:
# Total CSV files with more than 19 columns: 0
# Total number of CSV files: 1980

# %% [markdown]
# # clean type misplaced columns - mostly not gonna use this

# %%
import os
import shutil
import pandas as pd

# Define the source and destination directories
source_directory = 'path/to/source_directory'
destination_directory = 'path/to/destination_directory'

# Create the destination directory if it does not exist
if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

# Loop through each file in the source directory
for filename in os.listdir(source_directory):
    # Check if the file is a CSV
    if filename.endswith('.csv'):
        file_path = os.path.join(source_directory, filename)

        df = pd.read_csv(file_path)
        # Check for substrings and replace values in 'total_imprisonment_a'
        df.loc[df['total_imprisonment_a'].str.contains('无期', na=False), 'total_imprisonment_a'] = 9998
        df.loc[df['total_imprisonment_a'].str.contains('死刑', na=False), 'total_imprisonment_a'] = 9999

        # Save the modified DataFrame back to CSV
        df.to_csv(file_path, index=False)

        print("Modifications are complete and the file has been saved.")

print("Processing complete.")

# %% [markdown]
# # clean 无期徒刑、死刑. remove empty value. remove temp columns. write back to original location. tested

# %%
import os
import pandas as pd

# Path to the directory containing the CSV files
directory_path = '/Users/jiaruisong/Documents/Coding/INFO 288 Big Data and Development_Data/drug_related_full_dataset_type_amount_cleaned_penalty'

# Initialize overall counters for each condition
total_count_wuqi = 0
total_count_sixing = 0

# Loop through each file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.csv'):  # Check if the file is a CSV file
        file_path = os.path.join(directory_path, filename)
        df = pd.read_csv(file_path)
        
        #set flags of original columns and rows
        original_columns = set(df.columns)
        
        # Drop the specified columns if they exist in the DataFrame and check if a drop occurred

        df.drop(columns=['ResponseText', 'TrimmedType'], errors='ignore', inplace=True)


        # Drop rows where 'total_imprisonment_a' is NaN, empty, or contains only a space
        try:
            df = df.dropna(subset=['total_imprisonment_a'])  # Drop rows where this column is NaN
        except KeyError:
            print(f"Column 'total_imprisonment_a' not found in {filename}")
        
        # Convert 'total_imprisonment_a' to string to ensure string operations work
        df['total_imprisonment_a'] = df['total_imprisonment_a'].astype(str)
        df = df[df['total_imprisonment_a'].str.strip() != '']  # Remove rows where this column is empty or space only

        # Initialize counters for the current file
        count_wuqi = 0
        count_sixing = 0

        # Check for substrings and replace values in 'total_imprisonment_a'
        contains_wuqi = df['total_imprisonment_a'].str.contains('无期', na=False)
        contains_sixing = df['total_imprisonment_a'].str.contains('死刑', na=False)

        if contains_wuqi.any():
            count_wuqi = contains_wuqi.sum()  # Count the number of True values
            df.loc[contains_wuqi, 'total_imprisonment_a'] = 9998

        if contains_sixing.any():
            count_sixing = contains_sixing.sum()  # Count the number of True values
            df.loc[contains_sixing, 'total_imprisonment_a'] = 9999

        # Save the modified DataFrame back to CSV only if changes were made
        dropped_columns = original_columns - set(df.columns)
        columns_dropped_flag = len(dropped_columns) > 0
        original_count = pd.read_csv(file_path).shape[0]
        
        if count_wuqi > 0 or count_sixing > 0 or df.shape[0] != original_count or columns_dropped_flag:
            df.to_csv(file_path, index=False)
            print(f"Modified {filename}: '无期' changes: {count_wuqi}, '死刑' changes: {count_sixing}, Rows dropped: {original_count - df.shape[0]}")

        # Update total counts
        total_count_wuqi += count_wuqi
        total_count_sixing += count_sixing

# Print the total modifications after all files have been processed
print(f"Total modifications across all files: '无期' = {total_count_wuqi}, '死刑' = {total_count_sixing}")
# Out:
# Modified part-00043-tid-3342515310755238742-2e94fd7b-2d66-4cf3-b445-b2f56643ce20-3898-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00033-tid-8870043383557983114-473032ac-c43b-4b65-9fb7-8c170157e0c9-4335-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00004-tid-5337073424345691499-209e3284-258c-4dd6-ba04-b7d62b0bf4ad-4965-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00001-tid-8224862644505304205-87b17c42-1585-49e0-8711-f64fb7eefeeb-1277-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00010-tid-3342515310755238742-2e94fd7b-2d66-4cf3-b445-b2f56643ce20-3865-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00036-tid-1014278928818658117-550dace3-6c04-47ce-979a-66dd407a72b9-3736-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00017-tid-1014278928818658117-550dace3-6c04-47ce-979a-66dd407a72b9-3717-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00000-tid-2121029807467275532-4545430e-426d-48ce-9c4a-53de4ae6730c-2974-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00017-tid-7891592605338472512-5e1362cb-16fd-49e4-8fb3-a7039f9e5a05-1515-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00041-tid-8345041676783108651-73df31c9-464e-47ec-a3dc-0709c0a60d90-4620-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00026-tid-1323465143157338736-ff930471-9114-4d6c-b4e5-6b7541f28dcc-4155-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00017-tid-1323465143157338736-ff930471-9114-4d6c-b4e5-6b7541f28dcc-4146-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00003-tid-335610467100931792-8efcf179-6057-40aa-bd88-1d40c8d4e3de-1856-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00006-tid-1566816878721410657-3751a12a-84cf-40c6-add4-35e08d7323b1-4762-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00008-tid-2835676307537882535-d0d002c1-3e3e-4410-90dd-02caed0d285a-4433-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00008-tid-6879364726152781056-96ab9d6d-ae9e-45f8-9334-d2188a3c690a-4936-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00007-tid-8161392759403063486-c0f92cd1-b537-4bbb-8e8e-903fb66c293e-371-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00002-tid-1774310925749392111-a7c95fb6-a172-44be-983a-d2c243c84d7f-2800-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00015-tid-936569945664005488-5602fb5f-806a-4cbe-9e69-9b2c04deadd2-3282-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00004-tid-8885333525305868225-e1aa2550-2b31-4220-95b4-3430eb1bb826-1762-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00027-tid-6651406933924064188-efbe7d64-fbed-4129-b85b-6b344b438b77-3442-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00005-tid-6021341481081789638-4464dd4e-bbbe-47c9-827f-5899d7cef7d2-4891-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00003-tid-1323465143157338736-ff930471-9114-4d6c-b4e5-6b7541f28dcc-4132-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00000-tid-1014278928818658117-550dace3-6c04-47ce-979a-66dd407a72b9-3700-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00023-tid-5707708088734423729-95b6f48d-a233-49b7-af47-aaabd94b89d3-569-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00036-tid-1875109887902425094-bfe12b7e-1ac8-4d27-a384-16d2cb24e950-3601-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00012-tid-1566816878721410657-3751a12a-84cf-40c6-add4-35e08d7323b1-4768-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00000-tid-3312824128043469394-f52669de-9743-4cc1-bd2c-3d7ff3ee5d8a-43-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00027-tid-2869476611883994175-56ab2380-3004-4b22-8fb7-b0af39ed2a9f-4705-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00003-tid-4137380717972787387-6ec44b47-d659-4eff-aead-7d410af2373f-3046-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00006-tid-5149185796620252648-ec78fbd7-ac64-40b8-9c82-a0917ea4a1db-2431-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00005-tid-5942143975908276959-d09e7556-a489-4120-86af-43a3e53d4162-1137-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00001-tid-4061263354178871139-7546fba6-2c1e-4a9a-a8a9-fad862475eaf-1893-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00008-tid-1014278928818658117-550dace3-6c04-47ce-979a-66dd407a72b9-3708-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00010-tid-6021341481081789638-4464dd4e-bbbe-47c9-827f-5899d7cef7d2-4896-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00050-tid-8870043383557983114-473032ac-c43b-4b65-9fb7-8c170157e0c9-4352-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00022-tid-8870043383557983114-473032ac-c43b-4b65-9fb7-8c170157e0c9-4324-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00003-tid-8870043383557983114-473032ac-c43b-4b65-9fb7-8c170157e0c9-4305-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00006-tid-1014278928818658117-550dace3-6c04-47ce-979a-66dd407a72b9-3706-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00001-tid-4169140279769324862-af62b2d3-3e4b-4c26-9bf3-1d55523ea062-1415-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00012-tid-899378660303502663-a1412f7f-f50a-491f-8fea-b0cea8499e8e-1214-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00007-tid-6879364726152781056-96ab9d6d-ae9e-45f8-9334-d2188a3c690a-4935-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00020-tid-8345041676783108651-73df31c9-464e-47ec-a3dc-0709c0a60d90-4599-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00008-tid-8345041676783108651-73df31c9-464e-47ec-a3dc-0709c0a60d90-4587-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00006-tid-936569945664005488-5602fb5f-806a-4cbe-9e69-9b2c04deadd2-3273-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00001-tid-6651406933924064188-efbe7d64-fbed-4129-b85b-6b344b438b77-3416-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00000-tid-7113356701296728292-1878a159-87fb-4728-8833-eb4baf56ce3f-268-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00008-tid-8870043383557983114-473032ac-c43b-4b65-9fb7-8c170157e0c9-4310-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00017-tid-1566816878721410657-3751a12a-84cf-40c6-add4-35e08d7323b1-4773-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00027-tid-6668636964318347777-96f2d544-07ae-4550-bbf6-60cd5ce089ab-1087-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00004-tid-8870043383557983114-473032ac-c43b-4b65-9fb7-8c170157e0c9-4306-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00025-tid-8870043383557983114-473032ac-c43b-4b65-9fb7-8c170157e0c9-4327-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00082-tid-8870043383557983114-473032ac-c43b-4b65-9fb7-8c170157e0c9-4384-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00002-tid
1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00006-tid-5337073424345691499-209e3284-258c-4dd6-ba04-b7d62b0bf4ad-4967-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00007-tid-2869476611883994175-56ab2380-3004-4b22-8fb7-b0af39ed2a9f-4685-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00072-tid-8870043383557983114-473032ac-c43b-4b65-9fb7-8c170157e0c9-4374-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00012-tid-8510476554429228893-444be295-5949-44f2-9e60-11cc12e6ec0f-2636-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00002-tid-7143810800454225208-bafaa04b-0713-4027-ba9b-18c22e3617a9-2147-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00001-tid-4137380717972787387-6ec44b47-d659-4eff-aead-7d410af2373f-3044-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00007-tid-4179991833852908328-c0631bae-a6a3-4b88-abc6-b985c6673c45-1816-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00009-tid-1774310925749392111-a7c95fb6-a172-44be-983a-d2c243c84d7f-2807-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00031-tid-8345041676783108651-73df31c9-464e-47ec-a3dc-0709c0a60d90-4610-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00003-tid-6879364726152781056-96ab9d6d-ae9e-45f8-9334-d2188a3c690a-4931-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00004-tid-6510975564714990302-3bfa6bf2-3c3b-49a3-81fc-6648bf2046e9-991-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00040-tid-8345041676783108651-73df31c9-464e-47ec-a3dc-0709c0a60d90-4619-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00072-tid-3342515310755238742-2e94fd7b-2d66-4cf3-b445-b2f56643ce20-3927-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00003-tid-3342515310755238742-2e94fd7b-2d66-4cf3-b445-b2f56643ce20-3858-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00016-tid-6194725384779829736-e34b779a-ac33-4b5b-9b0b-d43caf95ef05-1721-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00004-tid-6879364726152781056-96ab9d6d-ae9e-45f8-9334-d2188a3c690a-4932-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00046-tid-3342515310755238742-2e94fd7b-2d66-4cf3-b445-b2f56643ce20-3901-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00011-tid-8345041676783108651-73df31c9-464e-47ec-a3dc-0709c0a60d90-4590-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00003-tid-2835676307537882535-d0d002c1-3e3e-4410-90dd-02caed0d285a-4428-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00006-tid-923072131783649796-9aeb67a9-2238-497a-ab20-0c245554e9bf-35-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00008-tid-1875109887902425094-bfe12b7e-1ac8-4d27-a384-16d2cb24e950-3573-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00007-tid-8510476554429228893-444be295-5949-44f2-9e60-11cc12e6ec0f-2631-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00002-tid-4137380717972787387-6ec44b47-d659-4eff-aead-7d410af2373f-3045-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00022-tid-1566816878721410657-3751a12a-84cf-40c6-add4-35e08d7323b1-4778-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00003-tid-1566816878721410657-3751a12a-84cf-40c6-add4-35e08d7323b1-4759-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00037-tid-8870043383557983114-473032ac-c43b-4b65-9fb7-8c170157e0c9-4339-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00007-tid-6021341481081789638-4464dd4e-bbbe-47c9-827f-5899d7cef7d2-4893-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Modified part-00048-tid-1323465143157338736-ff930471-9114-4d6c-b4e5-6b7541f28dcc-4177-1-c000.csv: '无期' changes: 0, '死刑' changes: 0, Rows dropped: 0
# Total modifications across all files: '无期' = 0, '死刑' = 0

# %% [markdown]
# # check how if columns are successfully dropped - should be 17 columns now.

# %%
import os
import pandas as pd

# Define the directory containing the CSV files
source_directory = '/Users/jiaruisong/Documents/Coding/INFO 288 Big Data and Development_Data/drug_related_full_dataset_type_amount_cleaned_penalty'

# Initialize a counter
count_files_wrong_columns = 0
number_of_files = 0

# Loop through each file in the source directory
for filename in os.listdir(source_directory):
    if filename.endswith('.csv'):  # Check if the file is a CSV
        file_path = os.path.join(source_directory, filename)
        number_of_files += 1
        
        # Try to read the CSV file
        try:
            df = pd.read_csv(file_path)
            # Check if the CSV file has more than 20 columns
            if df.shape[1] != 17:
                count_files_wrong_columns += 1
                print(f"File {filename} has {df.shape[1]} columns")
        except Exception as e:
            print(f'Failed to process {filename}: {e}')

# Print the total count of files with more than 20 columns
print(f"Total CSV files with wrong number of columns: {count_files_wrong_columns}")
print(f"Total number of CSV files: {number_of_files}")
# Out:
# Total CSV files with wrong number of columns: 0
# Total number of CSV files: 1979
